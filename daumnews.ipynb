# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.daum.net/breakingnews/society"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36"
}

res = requests.get(url, headers=headers)
res.encoding = "utf-8"

if res.ok:
    soup = BeautifulSoup(res.text, "html.parser")
    a_tags = soup.select("a.item_newsheadline2")
    print(f"총 {len(a_tags)}개의 뉴스 기사 찾음\n")
    for tag in a_tags:
        title_tag = tag.select_one("strong.tit_txt")
        if title_tag:
            title = title_tag.text.strip()
            link = tag["href"]
            print(f" {title}\n {link}\n")
else:
    print(f" 에러 발생: {res.status_code}")
# Out:
# 총 21개의 뉴스 기사 찾음
#
#  개헌론 탓?… 양당 원내대표 회동 무산 [6·3 조기대선 개막]
#  https://v.daum.net/v/20250408194942811
#
#  우원식, '단계적 개헌' 드라이브 건다...이재명·권영세 만나 밑작업도
#  https://v.daum.net/v/20250408190054670
#
#  이완규 헌법재판관 지명·여야 대치에 힘 빠지는 개헌론
#  https://v.daum.net/v/20250408180509086
#
#  "헌법 파괴하고 호헌?" vs "이재명, 개헌 말 뒤집기"
#  https://v.daum.net/v/20250408180410053
#
#  “적절한 개헌 시기는 ‘내년 지방선거’…文정부 실패 교훈 새겨 ‘연합정부’로 가야”
#  https://v.daum.net/v/20250408162121316
#
#  갈 데까지 가보자는 미·중‥"'경제적 핵겨울' 온다" 경고도
#  https://v.daum.net/v/20250408204910233
#
#  “나라살림 꼬락서니 잘 돌아간다”...역대 3번째 적자 기록한 재정
#  https://v.daum.net/v/20250408203910045
#
#  한덕수 전례 없는 재판관 지명... "명백한 월권, 헌재 신뢰 떨어뜨려"
#  https://v.daum.net/v/20250408202100582
#
#  무장 북한군 10여명 MDL 침범…'권력 공백기' 軍 경계 시험했나
#  https://v.daum.net/v/20250408201153366
#
#  한덕수, 尹 최측근 이완규 헌법재판관 지명‥"당장 철회하라"
#  https://v.daum.net/v/20250408194910801
#
#  '관세 충격 완화' 금융권 연이틀 분주…우리금융, 10.2조 금융지원(종합)
#  https://v.daum.net/v/20250408184910361
#
#  인니 증시, 긴 연휴 후 개장 직후 거래중단…약 8% 하락(종합)
#  https://v.daum.net/v/20250408183737079
#
#  이철우, 대선 출마 동시에 ‘장기 휴가’…APEC·산불 현안 ‘뒷전’ 우려
#  https://v.daum.net/v/20250408183005917
#
#  트럼프, 푸틴·김정은 부러웠나…본인 생일에 맞춰 군사 퍼레이드 계획
#  https://v.daum.net/v/20250408182746851
#
#  "모든 보도는 본질적으로 탐사보도, 주변에 관심 가져야"
#  https://v.daum.net/v/20250408175217633
#
#  기자·가수 겸업… 펜과 마이크로 방글라데시 삶 그리다
#  https://v.daum.net/v/20250408175038567
#
#  전력·수도·통신 이상 감지→AI로 고독사 예방한다
#  https://v.daum.net/v/20250408174559420
#
#  "제자에 패한 뒤 무관 전락···부모상 같은 고통이었죠"
#  https://v.daum.net/v/20250408173634060
#
#  대장장이가 제 직업입니다, 저는 그게 자랑스럽습니다
#  https://v.daum.net/v/20250408162102294
#
#  [그래픽] 북한군 MDL 침범 일지
#  https://v.daum.net/v/20250408194943813
#
#  너도 가담했지? [그림판]
#  https://v.daum.net/v/20250408193503397

# %%
import requests
from bs4 import BeautifulSoup

section_dict = {
    "politics": "정치",
    "economic": "경제",
    "society": "사회",
    "culture": "문화",
    "foreign": "국제",
    "digital": "IT",
}
