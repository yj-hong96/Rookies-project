# %%
import requests

# ✅ 1. 네이버 개발자센터에서 발급받은 클라이언트 ID와 시크릿 입력
# 🎯 여기에 본인의 값 입력
client_id = '8xWBKSelQiATYZJCce6v'         # 예: 'abcd1234abcd1234abcd'
client_secret = 'XUcKjn3UPc' # 예: 'efgh5678efgh5678efgh'

# ✅ 2. API 요청에 필요한 헤더
headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret': client_secret
}

# ✅ 3. 책 정보 출력 함수
def print_book_info(item):
    print('제목:', item['title'].replace('<b>', '').replace('</b>', ''))  # HTML 태그 제거
    print('저자:', item['author'])
    print('출판사:', item['publisher'])
    print('출판일:', item['pubdate'])
    print('ISBN:', item['isbn'])
    print('링크:', item['link'])
    print('-' * 40)

# ✅ 4. 책 검색 함수
def search_books(query):
    payload = {
        'query': query,
        'display': 30,
        'sort': 'sim'
    }

    url = 'https://openapi.naver.com/v1/search/book.json'

    res = requests.get(url, params=payload, headers=headers)

    if res.status_code == 200:
        items = res.json().get('items', [])
        if not items:
            print('검색 결과가 없습니다.')
        for item in items:
            print_book_info(item)
    else:
        print(f'❌ 요청 실패 (상태코드: {res.status_code})')
        print(res.text)

# ✅ 5. 실행 부분
if __name__ == '__main__':
    search_word = input('검색할 책 제목을 입력하세요: ')
    search_books(search_word)
# Out:
# 제목: 혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임, 맵, AI 챗봇 만들기|저자 직강 유튜브 강의, 오픈 채팅 제공)
# 저자: 문현일
# 출판사: 한빛미디어
# 출판일: 20250214
# ISBN: 9791169213271
# 링크: https://search.shopping.naver.com/book/catalog/52859338841
# ----------------------------------------
# 제목: 혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
# 저자: 윤인성
# 출판사: 한빛미디어
# 출판일: 20220601
# ISBN: 9791162245651
# 링크: https://search.shopping.naver.com/book/catalog/32507605957
# ----------------------------------------
# 제목: Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)
# 저자: 박응용
# 출판사: 이지스퍼블리싱
# 출판일: 20230615
# ISBN: 9791163034735
# 링크: https://search.shopping.naver.com/book/catalog/40354085633
# ----------------------------------------
# 제목: 밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
# 저자: 사이토 고키
# 출판사: 한빛미디어
# 출판일: 20250124
# ISBN: 9791169213387
# 링크: https://search.shopping.naver.com/book/catalog/52615553184
# ----------------------------------------
# 제목: 파이썬
# 저자: 홍의경
# 출판사: 생능출판
# 출판일: 20220309
# ISBN: 9788970506784
# 링크: https://search.shopping.naver.com/book/catalog/32460987987
# ----------------------------------------
# 제목: CODING BASICS PYTHON (파이썬)
# 저자: 김상민^장성식^김일태
# 출판사: 렉스미디어닷넷
# 출판일: 20220210
# ISBN: 9788959604210
# 링크: https://search.shopping.naver.com/book/catalog/32440944646
# ----------------------------------------
# 제목: 파이썬 (제2판)
# 저자: 염기원^오지영
# 출판사: 북두
# 출판일: 20220120
# ISBN: 9791166750991
# 링크: https://search.shopping.naver.com/book/catalog/32436240934
# ----------------------------------------
# 제목: 파이썬
# 저자: 천인국
# 출판사: 인피니티북스
# 출판일: 20170830
# ISBN: 9791185578330
# 링크: https://search.shopping.naver.com/book/catalog/32489150082
# ----------------------------------------
# 제목: 파이썬 (비전공자를위한 파이썬 기초 입문서)
# 저자: 김명호
# 출판사: 에듀웨이
# 출판일: 20190525
# ISBN: 9791186179369
# 링크: https://search.shopping.naver.com/book/catalog/32436003648
# ----------------------------------------
# 제목: 파이썬
# 저자: 염기원
# 출판사: 복두출판사
# 출판일: 20200820
# ISBN: 9791159069048
# 링크: https://search.shopping.naver.com/book/catalog/32490271648
# ----------------------------------------
# 제목: 파이썬
# 저자: 김영천
# 출판사: 기한재
# 출판일: 20200225
# ISBN: 9788970187990
# 링크: https://search.shopping.naver.com/book/catalog/32438172833
# ----------------------------------------
# 제목: 파이썬
# 저자: 서정원^김태령
# 출판사: 생능출판
# 출판일: 20190228
# ISBN: 9788970509723
# 링크: https://search.shopping.naver.com/book/catalog/32505098970
# ----------------------------------------
# 제목: 파이썬 (다양한 예제로 알로리즘 쉽게 분석하기)
# 저자: 김유진
# 출판사: 다본
# 출판일: 20190410
# ISBN: 9791188577255
# 링크: https://search.shopping.naver.com/book/catalog/32441765959
# ----------------------------------------
# 제목: 파이썬
# 저자: Y. Daniel Liang
# 출판사: 에피스테메
# 출판일: 20180302
# ISBN: 9788920028892
# 링크: https://search.shopping.naver.com/book/catalog/32441653441
# ----------------------------------------
# 제목: 파이썬
# 저자: Y. Daniel Liang
# 출판사: 생능출판
# 출판일: 20160205
# ISBN: 9788970508504
# 링크: https://search.shopping.naver.com/book/catalog/32504743740
# ----------------------------------------
# 제목: 파이썬 머신러닝 완벽 가이드 (다양한 캐글 예제와 함께 기초 알고리즘부터 최신 기법까지 배우는)
# 저자: 권철민
# 출판사: 위키북스
# 출판일: 20220421
# ISBN: 9791158393229
# 링크: https://search.shopping.naver.com/book/catalog/32485894885
# ----------------------------------------
# 제목: 내공의 파이썬 (한 권으로 끝내는 초보자용 코딩 입문서)
# 저자: 한선관
# 출판사: 자유아카데미
# 출판일: 20250315
# ISBN: 9791158087005
# 링크: https://search.shopping.naver.com/book/catalog/53550577590
# ----------------------------------------
# 제목: 독학 파이썬
# 저자: 야마다 요시히로
# 출판사: 정보문화사
# 출판일: 20241220
# ISBN: 9788956749891
# 링크: https://search.shopping.naver.com/book/catalog/51981118640
# ----------------------------------------
# 제목: 파이썬 마스터 (실생활 융합 예제로 배우는)
# 저자: 김종훈^김동건
# 출판사: 한빛아카데미
# 출판일: 20250117
# ISBN: 9791173400018
# 링크: https://search.shopping.naver.com/book/catalog/52509305501
# ----------------------------------------
# 제목: 파이썬 워크북
# 저자: 안기수
# 출판사: 생능출판
# 출판일: 20250115
# ISBN: 9791192932682
# 링크: https://search.shopping.naver.com/book/catalog/52417646624
# ----------------------------------------
# 제목: 코딩 자율학습 나도코딩의 파이썬 입문 (초보자 눈높이에 맞춘 친절한 프로그래밍 자습서)
# 저자: 나도코딩
# 출판사: 길벗
# 출판일: 20230220
# ISBN: 9791140703302
# 링크: https://search.shopping.naver.com/book/catalog/37828235624
# ----------------------------------------
# 제목: 파이썬 3 (프로그래밍을 배우기에 가장 재미있는 언어)
# 저자: 박상현
# 출판사: 한빛미디어
# 출판일: 20160210
# ISBN: 9788968482359
# 링크: https://search.shopping.naver.com/book/catalog/32485534946
# ----------------------------------------
# 제목: 파이썬 + AI (코드조각과 실행화면으로 배우는 코딩)
# 저자: 안용제^김남규
# 출판사: 디지털북스
# 출판일: 20240715
# ISBN: 9788960884571
# 링크: https://search.shopping.naver.com/book/catalog/48703888619
# ----------------------------------------
# 제목: 으뜸 파이썬 (개정판)
# 저자: 박동규^강영민
# 출판사: 생능출판
# 출판일: 20240614
# ISBN: 9791192932675
# 링크: https://search.shopping.naver.com/book/catalog/48359296619
# ----------------------------------------
# 제목: 파이썬 프로그래밍 (기초부터 딥러닝까지)
# 저자: 허준
# 출판사: 성안당
# 출판일: 20250312
# ISBN: 9788931575767
# 링크: https://search.shopping.naver.com/book/catalog/53415634237
# ----------------------------------------
# 제목: 이지파이썬 1 (그림과 스토리텔링으로 이해하는 쉽고 재미있는 파이썬)
# 저자: 한국인공지능아카데미
# 출판사: 클라우드북스
# 출판일: 20240901
# ISBN: 9788997793273
# 링크: https://search.shopping.naver.com/book/catalog/49922621623
# ----------------------------------------
# 제목: 이지파이썬 2 (그림과 스토리텔링으로 이해하는 쉽고 재미있는 파이썬)
# 저자: 한국인공지능아카데미
# 출판사: 클라우드북스
# 출판일: 20240901
# ISBN: 9788997793280
# 링크: https://search.shopping.naver.com/book/catalog/49926240618
# ----------------------------------------
# 제목: 이지파이썬 1 (그림과 스토리텔링으로 이해하는 쉽고 재미있는 파이썬)
# 저자: 한국인공지능아카데미
# 출판사: 클라우드북스
# 출판일: 20240901
# ISBN: 9788997793266
# 링크: https://search.shopping.naver.com/book/catalog/49922615621
# ----------------------------------------
# 제목: 파이썬 플러스
# 저자: 최희식
# 출판사: 인피니티북스
# 출판일: 20240731
# ISBN: 9791192373362
# 링크: https://search.shopping.naver.com/book/catalog/49800327644
# ----------------------------------------
# 제목: 엑셀X파이썬 (엑셀이 파이썬을 품었다)
# 저자: 정성일
# 출판사: 길벗
# 출판일: 20240730
# ISBN: 9791140710195
# 링크: https://search.shopping.naver.com/book/catalog/49255941621
# ----------------------------------------

# %%
2.검색어로 찾은 책 목록을 json 파일로 저장하기

# %%
import os
import json
import requests

# ✅ 1. 네이버 API 키 입력 (🎯 직접 입력!)
client_id = '8xWBKSelQiATYZJCce6v'
client_secret = 'XUcKjn3UPc'

headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret': client_secret
}

# ✅ 책 정보 출력 함수
def print_book_info(item):
    print('제목:', item['title'].replace('<b>', '').replace('</b>', ''))
    print('저자:', item['author'])
    print('출판사:', item['publisher'])
    print('출판일:', item['pubdate'])
    print('ISBN:', item['isbn'])
    print('링크:', item['link'])
    print('-' * 40)

# ✅ 책 검색 + JSON 저장 함수
def search_books(query):
    payload = {
        'query': query,
        'display': 30,
        'sort': 'sim'
    }

    url = 'https://openapi.naver.com/v1/search/book.json'

    res = requests.get(url, params=payload, headers=headers)

    if res.status_code == 200:
        items = res.json().get('items', [])

        if not items:
            print('❗ 검색 결과가 없습니다.')
            return

        # ✅ 화면에 출력
        for item in items:
            print_book_info(item)

        # ✅ 2. JSON 파일로 저장 (data/books.json)
        os.makedirs('data', exist_ok=True)
        with open('data/books.json', 'w', encoding='utf-8') as f:
            json.dump(items, f, ensure_ascii=False, indent=2)

        print(f'\n✅ 검색 결과가 data/books.json 에 저장되었습니다.')
    else:
        print(f'❌ 요청 실패 (상태코드: {res.status_code})')
        print(res.text)

# ✅ 실행부
if __name__ == '__main__':
    search_word = input('검색할 책 제목을 입력하세요: ')
    search_books(search_word)
# Out:
# 제목: 혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임, 맵, AI 챗봇 만들기|저자 직강 유튜브 강의, 오픈 채팅 제공)
# 저자: 문현일
# 출판사: 한빛미디어
# 출판일: 20250214
# ISBN: 9791169213271
# 링크: https://search.shopping.naver.com/book/catalog/52859338841
# ----------------------------------------
# 제목: 혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
# 저자: 윤인성
# 출판사: 한빛미디어
# 출판일: 20220601
# ISBN: 9791162245651
# 링크: https://search.shopping.naver.com/book/catalog/32507605957
# ----------------------------------------
# 제목: Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)
# 저자: 박응용
# 출판사: 이지스퍼블리싱
# 출판일: 20230615
# ISBN: 9791163034735
# 링크: https://search.shopping.naver.com/book/catalog/40354085633
# ----------------------------------------
# 제목: 밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
# 저자: 사이토 고키
# 출판사: 한빛미디어
# 출판일: 20250124
# ISBN: 9791169213387
# 링크: https://search.shopping.naver.com/book/catalog/52615553184
# ----------------------------------------
# 제목: 파이썬
# 저자: 홍의경
# 출판사: 생능출판
# 출판일: 20220309
# ISBN: 9788970506784
# 링크: https://search.shopping.naver.com/book/catalog/32460987987
# ----------------------------------------
# 제목: CODING BASICS PYTHON (파이썬)
# 저자: 김상민^장성식^김일태
# 출판사: 렉스미디어닷넷
# 출판일: 20220210
# ISBN: 9788959604210
# 링크: https://search.shopping.naver.com/book/catalog/32440944646
# ----------------------------------------
# 제목: 파이썬 (제2판)
# 저자: 염기원^오지영
# 출판사: 북두
# 출판일: 20220120
# ISBN: 9791166750991
# 링크: https://search.shopping.naver.com/book/catalog/32436240934
# ----------------------------------------
# 제목: 파이썬
# 저자: 천인국
# 출판사: 인피니티북스
# 출판일: 20170830
# ISBN: 9791185578330
# 링크: https://search.shopping.naver.com/book/catalog/32489150082
# ----------------------------------------
# 제목: 파이썬 (비전공자를위한 파이썬 기초 입문서)
# 저자: 김명호
# 출판사: 에듀웨이
# 출판일: 20190525
# ISBN: 9791186179369
# 링크: https://search.shopping.naver.com/book/catalog/32436003648
# ----------------------------------------
# 제목: 파이썬
# 저자: 염기원
# 출판사: 복두출판사
# 출판일: 20200820
# ISBN: 9791159069048
# 링크: https://search.shopping.naver.com/book/catalog/32490271648
# ----------------------------------------
# 제목: 파이썬
# 저자: 김영천
# 출판사: 기한재
# 출판일: 20200225
# ISBN: 9788970187990
# 링크: https://search.shopping.naver.com/book/catalog/32438172833
# ----------------------------------------
# 제목: 파이썬
# 저자: 서정원^김태령
# 출판사: 생능출판
# 출판일: 20190228
# ISBN: 9788970509723
# 링크: https://search.shopping.naver.com/book/catalog/32505098970
# ----------------------------------------
# 제목: 파이썬 (다양한 예제로 알로리즘 쉽게 분석하기)
# 저자: 김유진
# 출판사: 다본
# 출판일: 20190410
# ISBN: 9791188577255
# 링크: https://search.shopping.naver.com/book/catalog/32441765959
# ----------------------------------------
# 제목: 파이썬
# 저자: Y. Daniel Liang
# 출판사: 에피스테메
# 출판일: 20180302
# ISBN: 9788920028892
# 링크: https://search.shopping.naver.com/book/catalog/32441653441
# ----------------------------------------
# 제목: 파이썬
# 저자: Y. Daniel Liang
# 출판사: 생능출판
# 출판일: 20160205
# ISBN: 9788970508504
# 링크: https://search.shopping.naver.com/book/catalog/32504743740
# ----------------------------------------
# 제목: 파이썬 머신러닝 완벽 가이드 (다양한 캐글 예제와 함께 기초 알고리즘부터 최신 기법까지 배우는)
# 저자: 권철민
# 출판사: 위키북스
# 출판일: 20220421
# ISBN: 9791158393229
# 링크: https://search.shopping.naver.com/book/catalog/32485894885
# ----------------------------------------
# 제목: 내공의 파이썬 (한 권으로 끝내는 초보자용 코딩 입문서)
# 저자: 한선관
# 출판사: 자유아카데미
# 출판일: 20250315
# ISBN: 9791158087005
# 링크: https://search.shopping.naver.com/book/catalog/53550577590
# ----------------------------------------
# 제목: 독학 파이썬
# 저자: 야마다 요시히로
# 출판사: 정보문화사
# 출판일: 20241220
# ISBN: 9788956749891
# 링크: https://search.shopping.naver.com/book/catalog/51981118640
# ----------------------------------------
# 제목: 파이썬 마스터 (실생활 융합 예제로 배우는)
# 저자: 김종훈^김동건
# 출판사: 한빛아카데미
# 출판일: 20250117
# ISBN: 9791173400018
# 링크: https://search.shopping.naver.com/book/catalog/52509305501
# ----------------------------------------
# 제목: 파이썬 워크북
# 저자: 안기수
# 출판사: 생능출판
# 출판일: 20250115
# ISBN: 9791192932682
# 링크: https://search.shopping.naver.com/book/catalog/52417646624
# ----------------------------------------
# 제목: 코딩 자율학습 나도코딩의 파이썬 입문 (초보자 눈높이에 맞춘 친절한 프로그래밍 자습서)
# 저자: 나도코딩
# 출판사: 길벗
# 출판일: 20230220
# ISBN: 9791140703302
# 링크: https://search.shopping.naver.com/book/catalog/37828235624
# ----------------------------------------
# 제목: 파이썬 3 (프로그래밍을 배우기에 가장 재미있는 언어)
# 저자: 박상현
# 출판사: 한빛미디어
# 출판일: 20160210
# ISBN: 9788968482359
# 링크: https://search.shopping.naver.com/book/catalog/32485534946
# ----------------------------------------
# 제목: 파이썬 + AI (코드조각과 실행화면으로 배우는 코딩)
# 저자: 안용제^김남규
# 출판사: 디지털북스
# 출판일: 20240715
# ISBN: 9788960884571
# 링크: https://search.shopping.naver.com/book/catalog/48703888619
# ----------------------------------------
# 제목: 으뜸 파이썬 (개정판)
# 저자: 박동규^강영민
# 출판사: 생능출판
# 출판일: 20240614
# ISBN: 9791192932675
# 링크: https://search.shopping.naver.com/book/catalog/48359296619
# ----------------------------------------
# 제목: 파이썬 프로그래밍 (기초부터 딥러닝까지)
# 저자: 허준
# 출판사: 성안당
# 출판일: 20250312
# ISBN: 9788931575767
# 링크: https://search.shopping.naver.com/book/catalog/53415634237
# ----------------------------------------
# 제목: 이지파이썬 1 (그림과 스토리텔링으로 이해하는 쉽고 재미있는 파이썬)
# 저자: 한국인공지능아카데미
# 출판사: 클라우드북스
# 출판일: 20240901
# ISBN: 9788997793273
# 링크: https://search.shopping.naver.com/book/catalog/49922621623
# ----------------------------------------
# 제목: 이지파이썬 2 (그림과 스토리텔링으로 이해하는 쉽고 재미있는 파이썬)
# 저자: 한국인공지능아카데미
# 출판사: 클라우드북스
# 출판일: 20240901
# ISBN: 9788997793280
# 링크: https://search.shopping.naver.com/book/catalog/49926240618
# ----------------------------------------
# 제목: 이지파이썬 1 (그림과 스토리텔링으로 이해하는 쉽고 재미있는 파이썬)
# 저자: 한국인공지능아카데미
# 출판사: 클라우드북스
# 출판일: 20240901
# ISBN: 9788997793266
# 링크: https://search.shopping.naver.com/book/catalog/49922615621
# ----------------------------------------
# 제목: 파이썬 플러스
# 저자: 최희식
# 출판사: 인피니티북스
# 출판일: 20240731
# ISBN: 9791192373362
# 링크: https://search.shopping.naver.com/book/catalog/49800327644
# ----------------------------------------
# 제목: 엑셀X파이썬 (엑셀이 파이썬을 품었다)
# 저자: 정성일
# 출판사: 길벗
# 출판일: 20240730
# ISBN: 9791140710195
# 링크: https://search.shopping.naver.com/book/catalog/49255941621
# ----------------------------------------
#
# ✅ 검색 결과가 data/books.json 에 저장되었습니다.
